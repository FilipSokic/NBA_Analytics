# %% [markdown]
# # NBA Analytics

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import sklearn
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv("Players.csv")
df1.head()
# Out:
#    Unnamed: 0           Player  height  weight  \
# 0           0  Curly Armstrong   180.0    77.0
# 1           1     Cliff Barker   188.0    83.0
# 2           2    Leo Barnhorst   193.0    86.0
# 3           3       Ed Bartels   196.0    88.0
# 4           4      Ralph Beard   178.0    79.0
#
#                            collage    born   birth_city birth_state
# 0               Indiana University  1918.0          NaN         NaN
# 1           University of Kentucky  1921.0     Yorktown     Indiana
# 2         University of Notre Dame  1924.0          NaN         NaN
# 3  North Carolina State University  1925.0          NaN         NaN
# 4           University of Kentucky  1927.0  Hardinsburg    Kentucky

# %%
df1.shape
# Out:
# (3922, 8)

# %%
df2 = pd.read_csv('Seasons_Stats.csv')
df2.head()
# Out:
#    Unnamed: 0    Year           Player  Pos   Age   Tm     G  GS  MP  PER  \
# 0           0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN
# 1           1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN
# 2           2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN
# 3           3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN
# 4           4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN
#
#    ...      FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  ...    0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  ...    0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  ...    0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  ...    0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  ...    0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 53 columns]

# %% [markdown]
# # Plotting Player's Height's and Weight's Over Time

# %%
df2.shape
# Out:
# (24691, 53)

# %%
df1.head()
# Out:
#    Unnamed: 0           Player  height  weight  \
# 0           0  Curly Armstrong   180.0    77.0
# 1           1     Cliff Barker   188.0    83.0
# 2           2    Leo Barnhorst   193.0    86.0
# 3           3       Ed Bartels   196.0    88.0
# 4           4      Ralph Beard   178.0    79.0
#
#                            collage    born   birth_city birth_state
# 0               Indiana University  1918.0          NaN         NaN
# 1           University of Kentucky  1921.0     Yorktown     Indiana
# 2         University of Notre Dame  1924.0          NaN         NaN
# 3  North Carolina State University  1925.0          NaN         NaN
# 4           University of Kentucky  1927.0  Hardinsburg    Kentucky

# %%
df1.describe()
# Out:
#         Unnamed: 0       height       weight        born
# count  3922.000000  3921.000000  3921.000000  3921.00000
# mean   1960.500000   198.704922    94.783219  1962.37975
# std    1132.328206     9.269761    12.039515    20.33491
# min       0.000000   160.000000    60.000000  1913.00000
# 25%     980.250000   190.000000    86.000000  1948.00000
# 50%    1960.500000   198.000000    95.000000  1964.00000
# 75%    2940.750000   206.000000   102.000000  1979.00000
# max    3921.000000   231.000000   163.000000  1997.00000

# %% [markdown]
# ## Scatter Plot of Player's Heights Over Time

# %%
plt.scatter(df1['born'],df1['height'])
plt.show()

# %% [markdown]
# ## Scatter Plot of Player's Weights Over Time

# %%
plt.scatter(df1['born'], df1['weight'])
plt.show()

# %% [markdown]
# ## Histogram of Player's Heights Over Time

# %%
df1 = df1[np.isfinite(df1['height'])]
sns.distplot(df1['height'])
plt.show()

# %% [markdown]
# ## Histogram of Player's Weights Over Time

# %%
df1 = df1[np.isfinite(df1['weight'])]
sns.distplot(df1['weight'])
plt.show()

# %%
plt.subplots(figsize=(20,15))
sns.barplot(y='born', x='height', data=df1, orient = 'h')
plt.show()

# %%
plt.subplots(figsize=(30,25))
sns.barplot(y='born', x='weight', data=df1, orient = 'h')
plt.show()

# %% [markdown]
#  ### Conclusion: We find that the height of NBA players over time is more constant, whereas the weight of players increases over time

# %% [markdown]
# # Now we are going to look at how 3 point shooting in the NBA has changed over time

# %% [markdown]
# ### 3PA the first year the 3 point line was implented vs 3PA in 2017

# %%
first_year = df2[df2['Year'] == 1980.0]
first_year.head()
# Out:
#       Unnamed: 0    Year                Player Pos   Age   Tm     G    GS  \
# 5727        5727  1980.0  Kareem Abdul-Jabbar*   C  32.0  LAL  82.0   NaN
# 5728        5728  1980.0         Tom Abernethy  PF  25.0  GSW  67.0   NaN
# 5729        5729  1980.0           Alvan Adams   C  25.0  PHO  75.0   NaN
# 5730        5730  1980.0       Tiny Archibald*  PG  31.0  BOS  80.0  80.0
# 5731        5731  1980.0         Dennis Awtrey   C  31.0  CHI  26.0   NaN
#
#           MP   PER   ...      FT%    ORB    DRB    TRB    AST    STL    BLK  \
# 5727  3143.0  25.3   ...    0.765  190.0  696.0  886.0  371.0   81.0  280.0
# 5728  1222.0  11.0   ...    0.683   62.0  129.0  191.0   87.0   35.0   12.0
# 5729  2168.0  19.2   ...    0.797  158.0  451.0  609.0  322.0  108.0   55.0
# 5730  2864.0  15.3   ...    0.830   59.0  138.0  197.0  671.0  106.0   10.0
# 5731   560.0   7.4   ...    0.640   29.0   86.0  115.0   40.0   12.0   15.0
#
#         TOV     PF     PTS
# 5727  297.0  216.0  2034.0
# ...

# %%
this_year = df2[df2["Year"] == 2017]
this_year.head()
# Out:
#        Unnamed: 0    Year        Player Pos   Age   Tm     G    GS      MP  \
# 24096       24096  2017.0  Alex Abrines  SG  23.0  OKC  68.0   6.0  1055.0
# 24097       24097  2017.0    Quincy Acy  PF  26.0  TOT  38.0   1.0   558.0
# 24098       24098  2017.0    Quincy Acy  PF  26.0  DAL   6.0   0.0    48.0
# 24099       24099  2017.0    Quincy Acy  PF  26.0  BRK  32.0   1.0   510.0
# 24100       24100  2017.0  Steven Adams   C  23.0  OKC  80.0  80.0  2389.0
#
#         PER  ...      FT%    ORB    DRB    TRB   AST   STL   BLK    TOV  \
# 24096  10.1  ...    0.898   18.0   68.0   86.0  40.0  37.0   8.0   33.0
# 24097  11.8  ...    0.750   20.0   95.0  115.0  18.0  14.0  15.0   21.0
# 24098  -1.4  ...    0.667    2.0    6.0    8.0   0.0   0.0   0.0    2.0
# 24099  13.1  ...    0.754   18.0   89.0  107.0  18.0  14.0  15.0   19.0
# 24100  16.5  ...    0.611  282.0  333.0  615.0  86.0  88.0  78.0  146.0
#
#           PF    PTS
# 24096  114.0  406.0
# 24097   67.0  222.0
# ...

# %%
plt.subplots(figsize=(25,20))
sns.distplot(first_year['3PA'])
plt.show()

# %%
plt.subplots(figsize=(25,20))
sns.distplot(this_year['3PA'])
plt.show()

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP',
#        'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%',
#        'BLK%', 'TOV%', 'USG%', 'blanl', 'OWS', 'DWS', 'WS', 'WS/48', 'blank2',
#        'OBPM', 'DBPM', 'BPM', 'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%',
#        '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB',
#        'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %% [markdown]
# ### Change in 3 Pointers Attempted over Time

# %%
df2 = df2[np.isfinite(df2['3PAr'])]
plt.scatter(df2['Year'], df2['3PAr'])
plt.show()

# %%
plt.subplots(figsize=(30,25))
sns.barplot(x='Year', y='3PA', data=df2, orient = 'v')
plt.show()

# %% [markdown]
# #### Conclusion: As the NBA has progressed, player's have attempted more and more 3 point shots

# %% [markdown]
# ## The Evolution of Big Men 3pt Shooting

# %%
big_men = df2[df2['Pos'] == 'C']
big_men.head()
# Out:
#       Unnamed: 0    Year                Player Pos   Age   Tm     G  GS  \
# 5727        5727  1980.0  Kareem Abdul-Jabbar*   C  32.0  LAL  82.0 NaN
# 5729        5729  1980.0           Alvan Adams   C  25.0  PHO  75.0 NaN
# 5731        5731  1980.0         Dennis Awtrey   C  31.0  CHI  26.0 NaN
# 5743        5743  1980.0           Kent Benson   C  25.0  TOT  73.0 NaN
# 5744        5744  1980.0           Kent Benson   C  25.0  MIL  56.0 NaN
#
#           MP   PER   ...      FT%    ORB    DRB    TRB    AST    STL    BLK  \
# 5727  3143.0  25.3   ...    0.765  190.0  696.0  886.0  371.0   81.0  280.0
# 5729  2168.0  19.2   ...    0.797  158.0  451.0  609.0  322.0  108.0   55.0
# 5731   560.0   7.4   ...    0.640   29.0   86.0  115.0   40.0   12.0   15.0
# 5743  1891.0  13.1   ...    0.702  126.0  327.0  453.0  178.0   73.0   92.0
# 5744  1389.0  13.3   ...    0.680   96.0  237.0  333.0  127.0   54.0   74.0
#
#         TOV     PF     PTS
# 5727  297.0  216.0  2034.0
# ...

# %%
df2.shape
# Out:
# (18839, 53)

# %%
plt.subplots(figsize=(30,25))
sns.barplot(x='Year', y='3PA', data=big_men, orient = 'v')
plt.show()

# %% [markdown]
# #### Conclusion: NBA Centers have started shooting more threes recently

# %% [markdown]
# ## Correlation Between Stats

# %%
correlations = df2.corr()
mask = np.zeros_like(correlations, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(20,15))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
_ = sns.heatmap(correlations, mask=mask, cmap=cmap, vmax=.3, center=0,
                square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %% [markdown]
# ### This Heat Map Shows Similarities or Differences Between Different Stats
# #### Ex. When a player's block percentage (BLK%) is high, their Free throw percentage is low (FT%). This makes sense as centers are usually better at blocking and worse at shooting free throws
